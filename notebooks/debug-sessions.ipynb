# %% [markdown]
# Debug notes for sessions and analytics behavior.

# %% [markdown]
# TODOs:
# - fix2: Update /api/analytics to use isolated sessions (getAnySession)
# - fix3: Update /api/employee/teams to use getEmployeeSession
# - fix4: Verify admin employees and teams lists use isolated session and company filter correctly

# %% [markdown]
# Next steps:
# - Migrate /api/analytics, /api/employee/teams, /api/tasks/[taskId] to use getAnySession/getEmployeeSession/getAdminSession
# - Ensure all admin/employee dashboards and list pages use APIs that rely only on isolated cookies
